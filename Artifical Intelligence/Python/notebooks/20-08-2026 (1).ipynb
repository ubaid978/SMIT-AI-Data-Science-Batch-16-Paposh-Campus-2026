# %% [markdown]
# # Operators

# %% [markdown]
# # what is Operators
# An operator in Python is a special symbol or keyword used to perform computations and manipulations on data. The values or variables that the operator acts upon are called operands.

# %% [markdown]
# # Types Of Operators
#
#     Arithmetic operators
#
#     Camparsion Operators
#
#     Assignment Operators
#
#     Logical Operators
#
#     Identity Operator
#
#     Membership Operator
#
#     Bitwise Operators

# %% [markdown]
# # Arithmetic operators
#
#     Addtion (+)
#
#     Subtraction (-)
#
#     Multiplication (*)
#
#     Division (/)
#
#     Floor Division (//)
#
#     Exponent (**)
#
#     Modulous(Remainder) (%)

# %% [markdown]
# # Addtion

# %%
10+10
# Out:
# 20

# %%
10+15+10
# Out:
# 35

# %%
num_1=10
num_2=5
num_3=35
num_4=33
num_5=67

# %%
num_1
# Out:
# 10

# %%
num_2
# Out:
# 5

# %%
result=num_1+num_2

# %%
result
# Out:
# 15

# %%
num_3+num_1+num_5+num_4
# Out:
# 145

# %% [markdown]
# # Subtraction

# %%
num_1
# Out:
# 10

# %%
num_2
# Out:
# 5

# %%
num_1-num_2
# Out:
# 5

# %%
num_2-num_1
# Out:
# -5

# %%
num_4
# Out:
# 33

# %%
num_4-num_1-num_2
# Out:
# 18

# %% [markdown]
# # Multiplication

# %%
2*2
# Out:
# 4

# %%
num_1
# Out:
# 10

# %%
num_5
# Out:
# 67

# %%
num_4
# Out:
# 33

# %%
num_2
# Out:
# 5

# %%
num_1*2
# Out:
# 20

# %%
num_1*num_2
# Out:
# 50

# %%
total_amount=100000

# %%
total_amount*0.10
# Out:
# 10000.0

# %%
total_amount*0.25
# Out:
# 25000.0

# %%
total_amount*23/100
# Out:
# 23000.0

# %%
5*5+10
# Out:
# 35

# %%
10+10*8
# Out:
# 90

# %%
10*10/5*2
# Out:
# 40.0

# %%
5*10/2*4
# Out:
# 100.0

# %%
student_1_marks=66
student_2_marks=77
student_3_marks=88

# %%
(student_1_marks+student_2_marks+student_3_marks)/3
# Out:
# 77.0

# %%
total_cost=200000
total_revenue=250000

# %%
profit=total_revenue-total_cost

# %%
profit
# Out:
# 50000

# %%
ali_python_marks=99
ali_java_marks=33
ali_c_plus_plus=55

# %%
((ali_c_plus_plus+ali_java_marks+ali_python_marks)/300)*100
# Out:
# 62.33333333333333

# %% [markdown]
# ## Divison

# %%
4/2
# Out:
# 2.0

# %%
type(4/2)
# Out:
# float

# %%
5.4/3
# Out:
# 1.8

# %%
13.3/9.3
# Out:
# 1.4301075268817205

# %%
5/5
# Out:
# 1.0

# %%
'ubaid'/3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 'ubaid'/3
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
10/5/2
# Out:
# 1.0

# %% [markdown]
# ## Floor Divison

# %%
6//3
# Out:
# 2

# %%
type(6//3)
# Out:
# int

# %%
6/3
# Out:
# 2.0

# %%
11/5
# Out:
# 2.2

# %%
11//5
# Out:
# 2

# %% [markdown]
# ## Exponent  (Power)

# %%
2**2
# Out:
# 4

# %%
3**3
# Out:
# 27

# %%
5**3
# Out:
# 125

# %%
3x3x3

# %%
num_1=3
num_2=5

# %%
num_1**num_2
# Out:
# 243

# %% [markdown]
# ## Modulous Remainder) (%)

# %%
4%2
# Out:
# 0

# %%
5%2
# Out:
# 1

# %%
9%3
# Out:
# 0

# %%
15%2
# Out:
# 1

# %%
5%7
# Out:
# 5

# %%
4%7
# Out:
# 4

# %%
float(4%8)
# Out:
# 4.0

# %%
100%6
# Out:
# 4

# %%
200%10
# Out:
# 0

# %%
10%200
# Out:
# 10

# %%
9%3
# Out:
# 0

# %% [markdown]
# ## Camparsion Operators   >>>>>>>   True | False
#
#
#     Greater than (>)
#
#     Less than (<)
#
#     Equal To (==)
#
#     Not Equal To (!=)
#
#     Greater than Equal To  (>=)
#
#     Less Than Equal To (<=)

# %% [markdown]
# ## Greater than (>)

# %%
5>4
# Out:
# True

# %%
4>5
# Out:
# False

# %%
77>66
# Out:
# True

# %%
5>4>3
# Out:
# True

# %%
5>4>6
# Out:
# False

# %%
6>6>1
# Out:
# False

# %%
a=10
b=30
c=25
d=88

# %%
a>c
# Out:
# False

# %%
d>a
# Out:
# True

# %%
c>d
# Out:
# False

# %%
5.5>5.9
# Out:
# False

# %%
10.11>11
# Out:
# False

# %%
55.5643>55.5644
# Out:
# False

# %%
int(55.5643)
# Out:
# 55

# %%
int(55.5644)
# Out:
# 55

# %%
int(55.5643)>int(55.5644)
# Out:
# False

# %%
dollor=5

# %%
pkr=dollor*277.5

# %%
pkr
# Out:
# 1387.5

# %%
pkr==1387.4
# Out:
# False

# %%
int(pkr)
# Out:
# 1387

# %%
int(1387.4)
# Out:
# 1387

# %%
int(pkr)==int(1387.4)
# Out:
# True

# %%
'h'>'u'
# Out:
# False

# %%
# Askey Values

# %%
ord('u')
# Out:
# 117

# %%
ord('b')
# Out:
# 98

# %%
ord('p')
# Out:
# 112

# %%
ord('h')
# Out:
# 104

# %%
ord('u')
# Out:
# 117

# %%
ord('U')
# Out:
# 85

# %%
104>117
# Out:
# False

# %%
'ka'>'ki"'
# Out:
# False

# %%
ord('k')
# Out:
# 107

# %%
ord('a')
# Out:
# 97

# %%
ord('i')
# Out:
# 105

# %%
ord('k,a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 ord('k,a')
#
# TypeError: ord() expected a character, but string of length 3 found

# %%
10797>107105
# Out:
# False

# %%
chr(105)
# Out:
# 'i'

# %%
chr(107)
# Out:
# 'k'

# %%
chr(105)
# Out:
# 'i'

# %%
True>False
# Out:
# True

# %%
False>False
# Out:
# False

# %% [markdown]
# # Less Than (<)

# %%
55<44
# Out:
# False

# %%
age=18
weight=55.4
height=5.5

# %%
age<16
# Out:
# False

# %%
age<18
# Out:
# False

# %% [markdown]
# ## Equal To (==)

# %%
55==44
# Out:
# False

# %%
55==55
# Out:
# True

# %%
99==100
# Out:
# False

# %%
55.58378373==55.58378371
# Out:
# False

# %%
int(55.58378373)==int(55.58378371)
# Out:
# True

# %%
name='ubaid'

# %%
name
# Out:
# 'ubaid'

# %%
name=='ali'
# Out:
# False

# %%
ord('u')
# Out:
# 117

# %%
ord('b')
# Out:
# 98

# %%
ord('a')
# Out:
# 97

# %%
ord('i')
# Out:
# 105

# %%
ord('d')
# Out:
# 100

# %%
ord('l')
# Out:
# 108

# %%
   ubaid                ali
1179897105100           97108105

# %%
1179897105100==97108105
# Out:
# False

# %%
name=='ubaid'
# Out:
# True

# %%
1179897105100==1179897105100
# Out:
# True

# %% [markdown]
# ## Not Equal To (!=)

# %%
55!=55
# Out:
# False

# %%
99!=1
# Out:
# True

# %%
name!='ali'
# Out:
# True

# %%
name!='ubaid'
# Out:
# False

# %% [markdown]
# ## Greater than Equal To  (>=)

# %%
55>55
# Out:
# False

# %%
55>=55
# Out:
# True

# %%
55>=57
# Out:
# False

# %%
55>=22
# Out:
# True

# %%
22>=99
# Out:
# False

# %% [markdown]
# ##  Less Than Equal To (<=)

# %%
55<=54
# Out:
# False

# %%
22<=22
# Out:
# True
