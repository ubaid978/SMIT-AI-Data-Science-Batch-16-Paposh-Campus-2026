# %%
String Functions :
    
    lower
    
    upper
    
    count
    
    capitalize
    
    title
    
    replace
    
    find 
    
    index

# %% [markdown]
# ## strip :
#
#
#     Returns a trimmed version of the string
#
#     lstrip >>>>> left strip
#
#     rstrip>>>>>  right strip
#
#     strip >>>>>  both side strip

# %%
course='   cyber scurity  '

# %%
course
# Out:
# '   cyber scurity  '

# %%
course.lstrip()
# Out:
# 'cyber scurity  '

# %%
course.rstrip()
# Out:
# '   cyber scurity'

# %%
course=course.strip()

# %%
course
# Out:
# 'cyber scurity'

# %% [markdown]
# ## split

# %%
full_name='tasheen khan'

# %%
full_name
# Out:
# 'tasheen khan'

# %%
full_name.split()
# Out:
# ['tasheen', 'khan']

# %%
type(full_name.split())
# Out:
# list

# %%
full_name
# Out:
# 'tasheen khan'

# %%
full_name.split(sep='h')
# Out:
# ['tas', 'een k', 'an']

# %%
students='ubaid,ali,hassan,ahmed,asad'

# %%
students.split()
# Out:
# ['ubaid,ali,hassan,ahmed,asad']

# %%
students.split(',')
# Out:
# ['ubaid', 'ali', 'hassan', 'ahmed', 'asad']

# %%
students
# Out:
# 'ubaid,ali,hassan,ahmed,asad'

# %%
students.split('|')
# Out:
# ['ubaid,ali,hassan,ahmed,asad']

# %%
students
# Out:
# 'ubaid,ali,hassan,ahmed,asad'

# %%
students.split('a')
# Out:
# ['ub', 'id,', 'li,h', 'ss', 'n,', 'hmed,', 's', 'd']

# %%
students
# Out:
# 'ubaid,ali,hassan,ahmed,asad'

# %%
splited_students=students.split(',')

# %%
splited_students
# Out:
# ['ubaid', 'ali', 'hassan', 'ahmed', 'asad']

# %% [markdown]
# ## Join

# %%
','.join(splited_students)
# Out:
# 'ubaid,ali,hassan,ahmed,asad'

# %%
' '.join(splited_students)
# Out:
# 'ubaid ali hassan ahmed asad'

# %%
students
# Out:
# 'ubaid,ali,hassan,ahmed,asad'

# %%
t=students.split('a')

# %%
t
# Out:
# ['ub', 'id,', 'li,h', 'ss', 'n,', 'hmed,', 's', 'd']

# %%
'a'.join(t)
# Out:
# 'ubaid,ali,hassan,ahmed,asad'

# %%
name='hashim'

# %%
name
# Out:
# 'hashim'

# %%
name='ahmer abid'

# %%
split_name=name.split('a')

# %%
split_name
# Out:
# ['', 'hmer ', 'bid']

# %%
'a'.join(split_name)
# Out:
# 'ahmer abid'

# %%
'a'.join(name.split('a'))
# Out:
# 'ahmer abid'

# %%
full_name
# Out:
# 'tasheen khan'

# %%
full_name.split('e')
# Out:
# ['tash', '', 'n khan']

# %%
'e'.join(full_name.split('e'))
# Out:
# 'tasheen khan'

# %%
teachers='nasir ubaid hassan'

# %%
teachers.split(' ')
# Out:
# ['nasir', 'ubaid', 'hassan']

# %%
teacher_split=teachers.split(' ')

# %%
' '.join(teachers.split(' '))
# Out:
# 'nasir ubaid hassan'

# %%
'|'.join(teachers.split(' '))
# Out:
# 'nasir|ubaid|hassan'

# %%
teacher_split
# Out:
# ['nasir', 'ubaid', 'hassan']

# %%
'|'.join(teacher_split)
# Out:
# 'nasir|ubaid|hassan'

# %%
'|'.join(['mango','orange','apple'])
# Out:
# 'mango|orange|apple'

# %% [markdown]
# ## startwith >>> True | False :
#     Return True if S starts with the specified prefix, False otherwise.

# %%
full_name
# Out:
# 'tasheen khan'

# %%
full_name.startswith('t')
# Out:
# True

# %%
full_name.startswith('n')
# Out:
# False

# %%
full_name
# Out:
# 'tasheen khan'

# %%
full_name.startswith('ta')
# Out:
# True

# %%
full_name.startswith('tasheen')
# Out:
# True

# %%
full_name.startswith('Tasheen')
# Out:
# False

# %% [markdown]
# ## endswith :
#     Returns true if the string ends with the specified value

# %%
course
# Out:
# 'cyber scurity'

# %%
course.endswith('z')
# Out:
# False

# %%
course.endswith('y')
# Out:
# True

# %%
course.endswith('scurity')
# Out:
# True

# %%
course.endswith('cyber')
# Out:
# False

# %% [markdown]
# # casefold :
#    	Converts string into lower case

# %%
full_name
# Out:
# 'tasheen khan'

# %%
full_name.casefold()
# Out:
# 'tasheen khan'

# %%
txt = "Hello, And Welcome To My World!"

# %%
txt.casefold()
# Out:
# 'hello, and welcome to my world!'

# %% [markdown]
# ## center :
#     	Returns a centered string

# %%
full_name
# Out:
# 'tasheen khan'

# %%
full_name.center()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 full_name.center()
#
# TypeError: center expected at least 1 argument, got 0

# %%
full_name.center(100,'+')
# Out:
# '++++++++++++++++++++++++++++++++++++++++++++tasheen khan++++++++++++++++++++++++++++++++++++++++++++'

# %%
full_name.center(42,'p')
# Out:
# 'ppppppppppppppptasheen khanppppppppppppppp'

# %%
txt = "My name is Ståle"

# %%
txt.encode()
# Out:
# b'My name is St\xc3\xa5le'

# %%
txt = "My name is Ståle"

# %%
txt.encode(encoding='ascii',errors='ignore')
# Out:
# b'My name is Stle'

# %% [markdown]
# ## islower

# %%
full_name
# Out:
# 'tasheen khan'

# %%
full_name.islower()
# Out:
# True

# %%
full_name=full_name.upper()

# %%
full_name
# Out:
# 'TASHEEN KHAN'

# %%
full_name.islower()
# Out:
# False

# %%
full_name=full_name.title()

# %%
full_name
# Out:
# 'Tasheen Khan'

# %%
full_name.islower()
# Out:
# False

# %% [markdown]
# ## isupper

# %%
full_name
# Out:
# 'Tasheen Khan'

# %%
full_name.isupper()
# Out:
# False

# %%
full_name=full_name.upper()

# %%
full_name
# Out:
# 'TASHEEN KHAN'

# %%
full_name.isupper()
# Out:
# True

# %% [markdown]
# ## isdigit

# %%
full_name
# Out:
# 'TASHEEN KHAN'

# %%
full_name.isdigit()
# Out:
# False

# %%
age='18'

# %%
age.isdigit()
# Out:
# True

# %%
sentence='i am 18 years old'

# %%
sentence.isdigit()
# Out:
# False

# %%
weight='18.4'

# %%
weight.isdigit()
# Out:
# False

# %%
salary='50000'

# %%
salary.isdigit()
# Out:
# True

# %% [markdown]
# ## isdecimal

# %%
salary
# Out:
# '50000'

# %%
salary.isdecimal()
# Out:
# True

# %%
weight
# Out:
# '18.4'

# %%
weight.isdecimal()
# Out:
# False

# %%
'8345'.isdecimal()
# Out:
# True

# %%
# alphanum >>>> alphanumeric

# %%
full_name
# Out:
# 'TASHEEN KHAN'

# %%
full_name.isalnum()
# Out:
# False

# %%
full_name+=' 123'

# %%
full_name
# Out:
# 'TASHEEN KHAN 123'

# %%
full_name.isalnum()
# Out:
# False

# %%
txt = "Company12"

txt.isalnum()
# Out:
# True

# %%
# isalpha

# %%
full_name
# Out:
# 'TASHEEN KHAN 123'

# %%
txt
# Out:
# 'Company12'

# %%
txt.isalpha()
# Out:
# False

# %%
full_name
# Out:
# 'TASHEEN KHAN 123'

# %%
full_name='TASHEENKHAN123'

# %%
full_name.isalnum()
# Out:
# True

# %%
full_name.isalpha()
# Out:
# False

# %% [markdown]
# ## isspace

# %%
txt = "   "

txt.isspace()
# Out:
# True

# %%
full_name
# Out:
# 'TASHEENKHAN123'

# %%
full_name.isspace()
# Out:
# False

# %%
full_name='          '

# %%
full_name.isspace()
# Out:
# True

# %% [markdown]
# ## istittle

# %%
full_name='ali khan'

# %%
full_name
# Out:
# 'ali khan'

# %%
full_name.istitle()
# Out:
# False

# %%
full_name=full_name.title()

# %%
full_name
# Out:
# 'Ali Khan'

# %%
full_name.istitle()
# Out:
# True

# %%
# istitle

# %%
course='graphic design'

# %%
course.istitle()
# Out:
# False

# %%
course=course.title()

# %%
course
# Out:
# 'Graphic Design'

# %%
course.istitle()
# Out:
# True

# %% [markdown]
# ## isidentifier

# %%
student_1_age='29'
student_2_age='50'
student_3_age=student_1_age

# %%
id(student_1_age)
# Out:
# 140707019003560

# %%
id(student_2_age)
# Out:
# 140707019004232

# %%
id(student_3_age)
# Out:
# 140707019003560

# %%
student_1_age is student_2_age
# Out:
# False

# %%
student_1_age is student_3_age
# Out:
# True

# %%
student_1_age.isidentifier()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[178], line 1
# ----> 1 student_1_age.isidentifier(student_3_age)
#
# TypeError: str.isidentifier() takes no arguments (1 given)

# %%
full_name
# Out:
# 'Ali Khan'

# %%
full_name.isidentifier()
# Out:
# False

# %%
name='alikhan'

# %%
name.isidentifier()
# Out:
# True

# %%
a = "MyFolder"
b = "Demo002"
c = "2bring"
d = "my demo"

print(a.isidentifier())
print(b.isidentifier())
print(c.isidentifier())
print(d.isidentifier())
# Out:
# True
# True
# False
# False

# %%
a=a.lower()

# %%
a.isidentifier()
# Out:
# True
