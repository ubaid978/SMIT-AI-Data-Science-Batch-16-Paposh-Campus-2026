# %% [markdown]
# # Types Of Operators
#
#     Arithmetic operators
#
#     Camparsion Operators
#
#     Assignment Operators
#
#     Logical Operators
#
#     Identity Operator
#
#     Membership Operator
#
#     Bitwise Operators

# %% [markdown]
# ## Assignment Operators
#
#
#
#
#     Equal To (=)
#
#     Plus Equal To (+=)
#
#     Minus Equal To (-=)
#
#     Multiply Equal To (*=)
#
#     Divide Equal To (/=)
#
#     Floor Divison Equal to (//=)
#
#     Modulous Equal To (%=)
#
#     And Equal To (&=)
#
#     Or EQual TO (|=)

# %% [markdown]
# # Equal To

# %%
a=10

# %%
a
# Out:
# 10

# %% [markdown]
# ## Plus Equal To

# %%
a=10
b=20
c=5

# %%
a=a+2

# %%
a
# Out:
# 12

# %%
a+=3

# %%
a
# Out:
# 15

# %%
a+=5

# %%
a
# Out:
# 20

# %%
a+5
# Out:
# 25

# %%
a
# Out:
# 20

# %%
b
# Out:
# 20

# %%
b+8
# Out:
# 28

# %%
b
# Out:
# 20

# %%
b=b+8

# %%
b
# Out:
# 28

# %%
b
# Out:
# 28

# %%
b+=2

# %%
b
# Out:
# 30

# %%
a=10

# %%
a+=10

# %%
a
# Out:
# 40

# %% [markdown]
# ## Minus Equal To (-=)

# %%
age=25

# %%
age-=7

# %%
age
# Out:
# 18

# %% [markdown]
# <!-- Floor Division and Assign  -->

# %%
age=10

# %%
age//2
# Out:
# 5

# %%
age//=2

# %%
age
# Out:
# 5

# %% [markdown]
# ## Identity Operators
#
#     is
#
#     is not

# %%
name='ali'
name_1='ubaid'

# %% [markdown]
# # is Operator

# %%
id(name)
# Out:
# 2151605491824

# %%
id(name_1)
# Out:
# 2151605495536

# %%
name is name_1
# Out:
# False

# %%
a=10

# %%
b=a

# %%
a
# Out:
# 10

# %%
b
# Out:
# 10

# %%
id(a)
# Out:
# 140727017378888

# %%
id(b)
# Out:
# 140727017378888

# %%
id(a)==id(b)
# Out:
# True

# %%
a is b
# Out:
# True

# %%
num_1=10
num_2=30
num_3=num_1

# %%
id(num_1)
# Out:
# 140727017378888

# %%
id(num_2)
# Out:
# 140727017379528

# %%
id(num_3)
# Out:
# 140727017378888

# %%
num_1 is num_2
# Out:
# False

# %%
num_1 is num_3
# Out:
# True

# %% [markdown]
# ## is not

# %%
emp_1_salary=50000
emp_2_salary=100000
emp_3_salary=20000
emp_4_salary=emp_2_salary

# %%
emp_1_salary
# Out:
# 50000

# %%
emp_2_salary
# Out:
# 100000

# %%
emp_3_salary
# Out:
# 20000

# %%
emp_4_salary
# Out:
# 100000

# %%
emp_1_salary is not emp_4_salary
# Out:
# True

# %%
emp_4_salary is emp_2_salary
# Out:
# True

# %% [markdown]
# ## Membership Operators
#
#     its only work on collection
#
#     in
#
#     not in

# %% [markdown]
# ## in Operator

# %%
name='hassan'

# %%
'i' in name
# Out:
# False

# %%
a=10

# %%
0 in a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 0 in a
#
# TypeError: argument of type 'int' is not iterable

# %%
'as' in name
# Out:
# True

# %%
'hassan' in name
# Out:
# True

# %%
text='I love python programming'

# %%
'python' in text
# Out:
# True

# %%
'java' in text
# Out:
# False

# %%
'I' in text
# Out:
# True

# %%
'pRogramming' in text
# Out:
# False

# %%
in Operator its only work on any colletion any data structure is can find a particluar word or char

# %%
employee_name='ali khan'

# %%
'khan' in employee_name
# Out:
# True

# %%
'Khan' in employee_name
# Out:
# False

# %%
'an' in employee_name
# Out:
# True

# %%
'ali khan' in employee_name
# Out:
# True

# %% [markdown]
# # not in

# %%
employee_name
# Out:
# 'ali khan'

# %%
'khan' not in employee_name
# Out:
# False

# %%
'Khan' not in employee_name
# Out:
# True

# %%
'ubaid' not in employee_name
# Out:
# True
