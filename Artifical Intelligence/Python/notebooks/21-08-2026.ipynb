# %% [markdown]
# # Types Of Operators
#
#     Arithmetic operators
#
#     Camparsion Operators
#
#     Assignment Operators
#
#     Logical Operators
#
#     Identity Operator
#
#     Membership Operator
#
#     Bitwise Operators

# %% [markdown]
# ## Logical Operators
#
#   its only answer True | False
#
#     and
#
#     or
#
#     not

# %%
# And Operator 

    All Conditions are True

# %%
name='hassan'
age=18
marks=80
cnic=3383838332

# %%
name=='ubaid'
# Out:
# False

# %%
age>12
# Out:
# True

# %%
marks>90
# Out:
# False

# %%
name=='ubaid' and age>12 and marks>90
# Out:
# False

# %% [markdown]
# ## And Operator
#
#
#     1st condtion              2nd Condition                 And Output
#
#
#     True                        False                         False
#
#     True                         True                          True
#
#     False                         True                          False
#
#     False                          False                        False

# %%
name
# Out:
# 'hassan'

# %%
age
# Out:
# 18

# %%
marks
# Out:
# 80

# %%
cnic
# Out:
# 3383838332

# %%
name=='hassan'
# Out:
# True

# %%
age>17
# Out:
# True

# %%
marks>50
# Out:
# True

# %%
len(str(cnic))==14
# Out:
# False

# %%
name=='hassan' and age>17 and marks>50 and len(str(cnic))==14
# Out:
# False

# %% [markdown]
# # OR Operator
#
#     Only One Condition Are True So i say True
#
#
#     Condtion 1                    Condition 2                condition 3            OR Output
#
#
#     True                            False                      False                  True
#
#
#     False                            True                       False                 True
#
#
#     False                            False                       False                 False
#
#
#     True                             True                         True                 True

# %%
employee_name='ali'
salary=25000
depart='it'
emp_id=101

# %%
# 1st Condition 
emp_id==102
# Out:
# False

# %%
employee_name=='ali'
# Out:
# True

# %%
salary>15000
# Out:
# True

# %%
depart=='it'
# Out:
# True

# %%
emp_id==102 or employee_name=='ali' or salary>15000 or depart=='it'
# Out:
# True

# %%
emp_id==102 and employee_name=='ali' and salary>15000 and depart=='it'
# Out:
# False

# %%
movie_name='Money Hiest'
movie_income=20000000
Director='hassan'

# %%
movie_name=='Money Hiest'
# Out:
# True

# %%
movie_income>30000000
# Out:
# False

# %%
Director=='Ahmed'
# Out:
# False

# %%
movie_name=='Money Hiest' and movie_income>30000000 or Director=='Ahmed'
# Out:
# False

# %%
movie_name=='Money Hiest' and movie_income>30000000 or Director=='hassan'
# Out:
# True

# %%
movie_name=='Money Hiest' or movie_income>30000000 and Director=='hassan'
# Out:
# True

# %% [markdown]
# ## not

# %%
name
# Out:
# 'hassan'

# %%
age
# Out:
# 18

# %%
marks
# Out:
# 80

# %%
not name=='hassan'
# Out:
# False

# %%
not True
# Out:
# False

# %%
not movie_name=='Money Hiest' or movie_income>30000000 and not Director=='hassan'
# Out:
# False

# %%
product='soap'
price=50
quntity=500
total_price=price*quntity

# %%
product
# Out:
# 'soap'

# %%
price
# Out:
# 50

# %%
quntity
# Out:
# 500

# %%
total_price
# Out:
# 25000

# %%
Condtion 1  >>>>>   Product >>>>>>>>>>  Surf

Condition 2  >>>>>  Price >>>>>>>>>>  25< 

Condtion 3 >>>>>>>>  Quntity >>>>>   50>

# %%
# False              False        True
product=='surf' and price<25 or quntity>50
# Out:
# True

# %%
course_name='python'
duration_in_months=3
fees=1000
teacher='ubaid'
institute='smit'

# %%
1 Student >>>>  Ai Data science  >>> Duration 1year  >>> fess <500  teacher nasir hussain institute smit

# %%
course_name=='Ai Data science'
# Out:
# False

# %%
duration_in_months==12
# Out:
# False

# %%
fees<500
# Out:
# False

# %%
teacher=='ubaid'
# Out:
# True

# %%
institute=='smit'
# Out:
# True

# %%
teacher=='ubaid' and institute=='smit' or duration_in_months==12 or fees<500
# Out:
# True

# %%
x=10

# %%
isinstance(x,int)
# Out:
# True

# %%
isinstance(x,str)
# Out:
# False

# %%
isinstance(x,float)
# Out:
# False

# %%
name='nasir'

# %%
isinstance(name,str)
# Out:
# True

# %%
isinstance(name,int)
# Out:
# False

# %%
x = 10.0
y = (x < 100.0) and isinstance(x, float)

# %%
y
# Out:
# True

# %% [markdown]
# # TRUThY And Falsy

# %%
10 and 20
# Out:
# 20

# %%
bool(10)
# Out:
# True

# %%
bool(20)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
0 and 10
# Out:
# 0

# %%
bool(0)
# Out:
# False

# %%
bool('')
# Out:
# False

# %%
bool('hassan')
# Out:
# True

# %%
'' and 'nasir'
# Out:
# ''

# %%
bool([])
# Out:
# False

# %%
bool(-3)
# Out:
# True

# %%
0 and -3
# Out:
# 0

# %%
10 and 20
# Out:
# 20

# %%
10 or 20
# Out:
# 10

# %%
'' or 'kamran'
# Out:
# 'kamran'

# %%
[] '' {}

# %%
bool(10)
# Out:
# True

# %%
bool(20)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
10 and 5 and 66 and 0 and 99
# Out:
# 0

# %%
0 and 5
# Out:
# 0

# %%
10 and 20 or 30
# Out:
# 20

# %%
a = 100
b = 200

# %%
a and b
# Out:
# 200

# %%
x = -100
from math import sqrt

# %%
x > 0 or sqrt(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 x > 0 or sqrt(x)
#
# ValueError: math domain error
