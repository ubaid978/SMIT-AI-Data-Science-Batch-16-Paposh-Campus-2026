# %% [markdown]
# ## Strings Functions

# %%
full_name='hassan ali'

# %%
full_name.
# Out:
# 'hassan ali'

# %%
print len type

# %%
full_name.

# %%
age='10'

# %%
age.

# %%
lower('hi')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 lower('hi')
#
# NameError: name 'lower' is not defined

# %% [markdown]
# # Lower

# %%
sentence='PYTHON IS A GOOD LANGUAGE'

# %%
sentence.lower()
# Out:
# 'python is a good language'

# %%
sentence
# Out:
# 'PYTHON IS A GOOD LANGUAGE'

# %%
sentence=sentence.lower()

# %%
sentence
# Out:
# 'python is a good language'

# %%
name='Ali khan'

# %%
name.lower()
# Out:
# 'ali khan'

# %%
lower(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 lower(name)
#
# NameError: name 'lower' is not defined

# %% [markdown]
# # Upper

# %%
course='Artifical Intelligence'

# %%
course
# Out:
# 'Artifical Intelligence'

# %%
course=course.upper()

# %%
course
# Out:
# 'ARTIFICAL INTELLIGENCE'

# %%
course
# Out:
# 'ARTIFICAL INTELLIGENCE'

# %%
course.upper()
# Out:
# 'ARTIFICAL INTELLIGENCE'

# %%
course
# Out:
# 'ARTIFICAL INTELLIGENCE'

# %%
course+='l'

# %%
course
# Out:
# 'ARTIFICAL INTELLIGENCEl'

# %%
course.upper()
# Out:
# 'ARTIFICAL INTELLIGENCEL'

# %%
course.lower()
# Out:
# 'artifical intelligencel'

# %% [markdown]
# ## Captilize

# %%
sentence
# Out:
# 'python is a good language'

# %%
sentence.capitalize()
# Out:
# 'Python is a good language'

# %%
course
# Out:
# 'ARTIFICAL INTELLIGENCEl'

# %%
course=course.capitalize()

# %%
course
# Out:
# 'Artifical intelligencel'

# %% [markdown]
# ## title

# %%
sentence='my name is ali and i am 20 years old'

# %%
sentence.title()
# Out:
# 'My Name Is Ali And I Am 20 Years Old'

# %%
course
# Out:
# 'Artifical intelligencel'

# %%
course.title()
# Out:
# 'Artifical Intelligencel'

# %%
sentence=sentence.upper()

# %%
sentence
# Out:
# 'MY NAME IS ALI AND I AM 20 YEARS OLD'

# %%
sentence=sentence.title()

# %%
sentence
# Out:
# 'My Name Is Ali And I Am 20 Years Old'

# %% [markdown]
# ## Count

# %%
course
# Out:
# 'Artifical intelligencel'

# %%
course.count('i')
# Out:
# 4

# %%
course.count('t')
# Out:
# 2

# %%
course.count('e')
# Out:
# 3

# %%
name='Ahmed ali'

# %%
name.count('a')
# Out:
# 1

# %%
name.lower().count('a')
# Out:
# 2

# %%
sentence
# Out:
# 'My Name Is Ali And I Am 20 Years Old'

# %%
sentence.count('Al')
# Out:
# 1

# %%
sentence=sentence.lower()

# %%
sentence
# Out:
# 'my name is ali and i am 20 years old'

# %%
sentence.count('is')
# Out:
# 1

# %%
# sentence.count('a')

# %%
sentence.count('a')
# Out:
# 5

# %%
sentence.count('a',18)
# Out:
# 2

# %%
name
# Out:
# 'Ahmed ali'

# %%
course
# Out:
# 'Artifical intelligencel'

# %%
course.count('t')
# Out:
# 2

# %%
course.count('t',9)
# Out:
# 1

# %% [markdown]
# ## Find

# %%
name
# Out:
# 'Ahmed ali'

# %%
name.find('A')
# Out:
# 0

# %%
name.find('l')
# Out:
# 7

# %%
name=name.title()

# %%
name
# Out:
# 'Ahmed Ali'

# %%
name.find('A')
# Out:
# 0

# %%
name.find('A',1)
# Out:
# 6

# %%
name+=' Amir'

# %%
name
# Out:
# 'Ahmed Ali Amir'

# %%
name.find('A',7)
# Out:
# 10

# %%
name[name.find('A',7)]
# Out:
# 'A'

# %%
name
# Out:
# 'Ahmed Ali Amir'

# %%
fruit='apple'

# %%
fruit.find('p')
# Out:
# 1

# %%
fruit.find('p',2)
# Out:
# 2

# %%
fruit.find('m')
# Out:
# -1

# %%
# Index

# %%
fruit
# Out:
# 'apple'

# %%
fruit.index('a')
# Out:
# 0

# %%
fruit.index('m')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 fruit.index('m')
#
# ValueError: substring not found

# %%
sentence
# Out:
# 'my name is ali and i am 20 years old'

# %%
sentence.find('o')
# Out:
# 33

# %%
sentence[33]
# Out:
# 'o'

# %%
sentence[sentence.find('o')]
# Out:
# 'o'

# %%
index=sentence.find('o')

# %%
index
# Out:
# 33

# %%
sentence[index]
# Out:
# 'o'

# %%
sentence
# Out:
# 'my name is ali and i am 20 years old'

# %%
sentence[sentence.index('2')]
# Out:
# '2'

# %%
sentence[24]
# Out:
# '2'

# %%
sentence='my name 2 is ali and i am 0 years old'

# %%
sentence[24]
# Out:
# 'm'

# %%
sentence[sentence.index('2')]
# Out:
# '2'

# %%
sentence.index('2')
# Out:
# 8

# %%
sentence[8]

# %%
sentence[sentence.index('2')]
# Out:
# '2'

# %% [markdown]
# ## replace

# %%
full_name='nasir hussain'

# %%
full_name
# Out:
# 'nasir hussain'

# %%
full_name.replace('a','e')
# Out:
# 'nesir hussein'

# %%
full_name
# Out:
# 'nasir hussain'

# %%
full_name=full_name.replace('a','e')

# %%
full_name
# Out:
# 'nesir hussein'

# %%
full_name.replace('s','i')
# Out:
# 'neiir huiiein'

# %%
full_name=full_name.replace('hussein','hussain')

# %%
full_name
# Out:
# 'nesir hussain'

# %%
full_name.replace('s','f',4)
# Out:
# 'nefir huffain'

# %%
full_name
# Out:
# 'nesir hussain'

# %%
full_name.index('h')
# Out:
# 6

# %%
full_name.index('n',2)
# Out:
# 12

# %%
full_name[6:13]
# Out:
# 'hussain'

# %%
full_name[0:6]
# Out:
# 'nesir '

# %%
full_name[full_name.index('h'):full_name.index('n',2)+1].replace('s','f')
# Out:
# 'huffain'

# %%
full_name[0:6]+full_name[full_name.index('h'):full_name.index('n',2)+1].replace('s','f')
# Out:
# 'nesir huffain'
