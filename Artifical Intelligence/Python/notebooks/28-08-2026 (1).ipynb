# %% [markdown]
# # Types Of Operators
#
#     Arithmetic operators
#
#     Camparsion Operators
#
#     Assignment Operators
#
#     Logical Operators
#
#     Identity Operator
#
#     Membership Operator
#
#     Bitwise Operators

# %% [markdown]
# ## Bitwise Operator
#
#
#     And (&)
#
#
#     OR (|)
#
#     XOR (^)
#
#     Not (~)

# %% [markdown]
# ## Binary AND (&)

# %%
7&9
# Out:
# 1

# %%
15&20
# Out:
# 4

# %%
bin(15)
# Out:
# '0b1111'

# %%
bin(20)
# Out:
# '0b10100'

# %%
01111  >>>> 15
10100 >>>> 20
00100

# %%
int('0b0100',2)
# Out:
# 4

# %%
bin(3)
# Out:
# '0b11'

# %%
bin(2)
# Out:
# '0b10'

# %%
bin(3)
# Out:
# '0b11'

# %%
10&20
# Out:
# 0

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(20)
# Out:
# '0b10100'

# %%
10  >>>>>>  01010
20 >>>>>>   10100

And >>>>>>>>00000

# %% [markdown]
# ## OR (|)

# %%
25|88
# Out:
# 89

# %%
bin(25)
# Out:
# '0b11001'

# %%
bin(88)
# Out:
# '0b1011000'

# %%
25 >>>>>>   0011001

88 >>>>>    1011000

OR >>>>>>>> 1011001

# %%
int('0b1011001',2)
# Out:
# 89

# %%
88&99
# Out:
# 64

# %%
bin(88)
# Out:
# '0b1011000'

# %%
bin(99)
# Out:
# '0b1100011'

# %%
88 >>>>> 1011000
99 >>>>> 1100011
&>>>>>>> 1000000
# Out:
#   Cell In[26], line 1
#     88 >>>>> 1011000
#          ^
# SyntaxError: invalid syntax

# %%
int('0b1000000',2)
# Out:
# 64

# %%
# XOR ^

# %%
13^19
# Out:
# 30

# %%
bin(13)
# Out:
# '0b1101'

# %%
bin(19)
# Out:
# '0b10011'

# %%
13 >>>>> 01101
19 >>>>> 10011
^ >>>>>> 11110

# %%
int('0b11110',2)
# Out:
# 30

# %%
~0
# Out:
# -1

# %%
bin(0)
# Out:
# '0b0'

# %%
0 >>>>>>>>  0
~ >>>>>>>>  1

# %%
int('0b1',2)
# Out:
# 1

# %%
print(2 ** 3 ** 2)
# Out:
# 512

# %%
2**3**2
# Out:
# 512

# %%
(10+10+10)**3
# Out:
# 27000

# %%
30**3
# Out:
# 27000

# %%
result = 10 / 2* 3
print(result)
# Out:
# 15.0

# %%
10/2*3
# Out:
# 15.0

# %%
result = 10 / 2 * 3

# %%
result
# Out:
# 15.0

# %%
2 * 2 ** 2 * 2
# Out:
# 16

# %%
((2 * 2) ** 2) * 2
# Out:
# 32
