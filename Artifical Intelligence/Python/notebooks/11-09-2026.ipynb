# %%
# MIni Project 


    Student Card Generator

# %%
student_Id=int(input('enter the student id'))
name=input('enter the name')
father_name=input('enter the father name ')
cnic=input('enter the valid cnic number ')
age=input('enter the age ')
email=input('enter your email address ')
address=input('enter your home adrress ')
print(f'''
______________________________________________________________________________


                                ABC Grammer School 
                                
______________________________________________________________________________


        Student id : {student_Id}                   Student Name : {name}
        
        
        Father Name : {father_name}                 Cnic : {cnic}
        
        
        Age : {age} years old                    Email Address :{email}
        
        
        Address : {address}
        
        
        


    __________________                                 ___________________

        Student Sign                                        Principle Sign
        
        ''')
# Out:
# enter the student id101
# enter the namefaizan
# enter the father name jammeel
# enter the valid cnic number 3674633636634
# enter the age 18
# enter your email address faizan@gmail.com
# enter your home adrress smit paposh
#
# ______________________________________________________________________________
#
#
#                                 ABC Grammer School
#
# ______________________________________________________________________________
#
#
#         Student id : 101                   Student Name : faizan
#
#
#         Father Name : jammeel                 Cnic : 3674633636634
#
#
#         Age : 18 years old                    Email Address :faizan@gmail.com
#
#
#         Address : smit paposh
#
#
#
#
#
#     __________________                                 ___________________
#
#         Student Sign                                        Principle Sign

# %%
## List 

### what is List ? :
# Out:
#   Cell In[2], line 3
#     what is List ?
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Python STructure / Collection :
#
#
#     string :
#
#         it is a collecction charcter
#
#         string is Immutable
#
#         string are indexable
#
#         string are slicable
#
#     List :
#         its a collection of items
#
#         list are mutable
#
#         list are indexable
#
#         list are sliceable
#
#     Tuple
#
#
#     dictionary
#
#
#     set

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## List
#     Lists are used to store multiple items in a single variable.
#
#     Lists are one of 4 built-in data types in Python used to store collections of data, the other 3 are Tuple, Set, and Dictionary, all with different qualities and usage.
#
#     Lists are created using square brackets:
#
# Example

# %%
student_1_name='hassan'
student_2_name='ali'
student_3_name='jammel'

# %%
# List []

# %%
#empty list
my_list=[]

# %%
type(my_list)
# Out:
# list

# %%
my_list=list()

# %%
type(my_list)
# Out:
# list

# %%
student_1_name='hassan'
student_2_name='ali'
student_3_name='jammel'

# %%
students=['hassan','ali','jammel']

# %%
students
# Out:
# ['hassan', 'ali', 'jammel']

# %%
type(students)
# Out:
# list

# %%
len(students)
# Out:
# 3

# %%
student_1_name
# Out:
# 'hassan'

# %%
len(student_1_name)
# Out:
# 6

# %%
students
# Out:
# ['hassan', 'ali', 'jammel']

# %%
len(students)
# Out:
# 3

# %%
fruits=['mango','orange','banana','cherry','pineapple','stawberry']

# %%
len(fruits)
# Out:
# 6

# %%
There are 5 fruit i have
# Out:
#   Cell In[25], line 1
#     There are 5 fruit i have
#           ^
# SyntaxError: invalid syntax

# %%
print(f'I have {len(fruits)} fruits in a list')
# Out:
# I have 6 fruits in a list

# %%
ages=[22,34,56,76,55,33]

# %%
ages
# Out:
# [22, 34, 56, 76, 55, 33]

# %%
all_dtype_list=['ubaid',18,55.6,False]

# %%
all_dtype_list
# Out:
# ['ubaid', 18, 55.6, False]

# %%
list(['ubaid','ali'])
# Out:
# ['ubaid', 'ali']

# %%
# List Indxing 

    Postive Indexing 
    
    Negative Indexing 
    
               -6         -5       -4     -3           -2          -1
            ['mango','orange','banana','cherry','pineapple','stawberry']
        
                0        1       2         3         4           5

# %% [markdown]
# ## Indexing

# %%
fruits=['mango','orange','banana','cherry','pineapple','stawberry']

# %%
fruits[0]
# Out:
# 'mango'

# %%
name='imran'

# %%
name[0]
# Out:
# 'i'

# %%
type(fruits[0])
# Out:
# str

# %%
all_dtype_list=['ubaid',18,55.6,False]

# %%
type(all_dtype_list[0])
# Out:
# str

# %%
type(all_dtype_list[1])
# Out:
# int

# %%
type(all_dtype_list[2])
# Out:
# float

# %%
type(all_dtype_list)
# Out:
# list

# %%
fruits=['mango','orange','banana','cherry','pineapple','stawberry']

# %% [markdown]
# ## POstive Indexing

# %%
fruits[0]
# Out:
# 'mango'

# %%
fruits[1]
# Out:
# 'orange'

# %%
fruits[2]
# Out:
# 'banana'

# %%
fruits[3]
# Out:
# 'cherry'

# %%
fruits[4]
# Out:
# 'pineapple'

# %%
fruits[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 fruits[10]
#
# IndexError: list index out of range

# %%
fruits=['mango','orange','banana','cherry','pineapple','stawberry']

# %%
fruits[0][-1]
# Out:
# 'o'

# %%
fruits[2][-4]
# Out:
# 'n'

# %%
fruits[5][4:-1]
# Out:
# 'berr'

# %%
all_dtype_list
# Out:
# ['ubaid', 18, 55.6, False]

# %%
all_dtype_list[0][1]
# Out:
# 'b'

# %%
all_dtype_list[1][1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 all_dtype_list[1][1]
#
# TypeError: 'int' object is not subscriptable

# %%
fruits=['mango','orange','banana','cherry','pineapple','stawberry']

# %%
# Negative Indexing

# %%
employees=['ali khan','ahmed abid','asad ali','mashab','faisal']

# %%
employees
# Out:
# ['ali khan', 'ahmed abid', 'asad ali', 'mashab', 'faisal']

# %%
employees[-1]
# Out:
# 'faisal'

# %%
employees[-2]
# Out:
# 'mashab'

# %%
employees[-5]
# Out:
# 'ali khan'

# %%
employees[-10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 employees[-10]
#
# IndexError: list index out of range

# %%
-len(employees)
# Out:
# -5

# %%
employees
# Out:
# ['ali khan', 'ahmed abid', 'asad ali', 'mashab', 'faisal']

# %%
-len(employees)
# Out:
# -5

# %%
employees[-len(employees)]
# Out:
# 'ali khan'

# %%
employees
# Out:
# ['ali khan', 'ahmed abid', 'asad ali', 'mashab', 'faisal']

# %%
len(employees)-3
# Out:
# 2

# %%
employees[len(employees)-3]
# Out:
# 'asad ali'

# %%
## SLicing 

structure :
    
    [start loc : end loc : step]   >>>>>>>>>>  by default >>>>>>>>>>>  [0:-1:1]

# %%
employees
# Out:
# ['ali khan', 'ahmed abid', 'asad ali', 'mashab', 'faisal']

# %%
employees[1:2]
# Out:
# ['ahmed abid']

# %%
employees[1:3]
# Out:
# ['ahmed abid', 'asad ali']

# %%
employees[1:4]
# Out:
# ['ahmed abid', 'asad ali', 'mashab']

# %%
fruits
# Out:
# ['mango', 'orange', 'banana', 'cherry', 'pineapple', 'stawberry']

# %%
fruits[-1:-4]
# Out:
# []

# %%
fruits[-3:]
# Out:
# ['cherry', 'pineapple', 'stawberry']

# %%
fruits
# Out:
# ['mango', 'orange', 'banana', 'cherry', 'pineapple', 'stawberry']

# %%
fruits[:5]
# Out:
# ['mango', 'orange', 'banana', 'cherry', 'pineapple']

# %%
fruits
# Out:
# ['mango', 'orange', 'banana', 'cherry', 'pineapple', 'stawberry']

# %%
fruits[::-1]
# Out:
# ['stawberry', 'pineapple', 'cherry', 'banana', 'orange', 'mango']

# %%
fruits
# Out:
# ['mango', 'orange', 'banana', 'cherry', 'pineapple', 'stawberry']

# %%
fruits[::2]

# %%
[start loc : end loc: step]  >>>   [2:3]>>>> by default  1

# %%
fruits
# Out:
# ['mango', 'orange', 'banana', 'cherry', 'pineapple', 'stawberry']

# %%
fruits[2:4:1]
# Out:
# ['banana', 'cherry']

# %%
fruits[::1]
# Out:
# ['mango', 'orange', 'banana', 'cherry', 'pineapple', 'stawberry']

# %%
fruits
# Out:
# ['mango', 'orange', 'banana', 'cherry', 'pineapple', 'stawberry']

# %%
fruits[::2]
# Out:
# ['mango', 'banana', 'pineapple']

# %%
fruits[::3]
# Out:
# ['mango', 'cherry']

# %%
fruits
# Out:
# ['mango', 'orange', 'banana', 'cherry', 'pineapple', 'stawberry']

# %%
fruits[1:5:2]
# Out:
# ['orange', 'cherry']

# %%
fruits
# Out:
# ['mango', 'orange', 'banana', 'cherry', 'pineapple', 'stawberry']

# %%
fruits[1::3]
# Out:
# ['orange', 'pineapple']

# %%
fruits
# Out:
# ['mango', 'orange', 'banana', 'cherry', 'pineapple', 'stawberry']

# %%
fruits[-3:-6:-1]
# Out:
# ['cherry', 'banana', 'orange']

# %%
fruits
# Out:
# ['mango', 'orange', 'banana', 'cherry', 'pineapple', 'stawberry']

# %%
fruits[-5:-2:-1]
# Out:
# []

# %%
fruits
# Out:
# ['mango', 'orange', 'banana', 'cherry', 'pineapple', 'stawberry']

# %%
fruits[::1]
# Out:
# ['mango', 'orange', 'banana', 'cherry', 'pineapple', 'stawberry']

# %%
fruits[::-1]
# Out:
# ['stawberry', 'pineapple', 'cherry', 'banana', 'orange', 'mango']

# %%
# LIst UPdate
