# %%
print('hello world')
# Out:
# hello world

# %%
print('this is a program')
# Out:
# this is a program

# %% [markdown]
# Introduction to Python

# %% [markdown]
# print('this is a program')

# %%
Heading :
    
    # text heading 1
    
    ## text Heading 2
    
    ### text heading 3

# %% [markdown]
# # Introduction to Python H1

# %% [markdown]
# ## Itroduction to Python H2

# %% [markdown]
# ### Itroduction to Python H3

# %%
# Print Function 


what is print function ?

its print a any object

# %%
print('this is a first program')
# Out:
# this is a first program

# %%
print(3636)
# Out:
# 3636

# %%
print(5.5)
# Out:
# 5.5

# %%
print(True)
# Out:
# True

# %% [markdown]
# # Multiple Values Print

# %%
print('Hello world',123,'ubaid','ali')
# Out:
# Hello world 123 ubaid ali

# %%
print('ubaid',18,60.3,'4838383838',sep='o')
# Out:
# ubaido18o60.3o4838383838

# %%
print('Hello \nmy name is \n ubaid')
# Out:
# Hello
# my name is
#  ubaid

# %%
print('Hello\t my name is \t ubaid')
# Out:
# Hello	 my name is 	 ubaid

# %% [markdown]
# # Print Multiple Lines

# %%
print('hussain',18,60)
print('ali',25,75)
print('nasir',23,44)
print('hashim',14,55)
# Out:
# hussain 18 60
# ali 25 75
# nasir 23 44
# hashim 14 55

# %%
print('hussain',18,60,end=' ',sep='|')
print('ali',25,75,end=' ',sep='|')
print('nasir',23,44,end=' ',sep='|')
print('hashim',14,55)
# Out:
# hussain|18|60 ali|25|75 nasir|23|44 hashim 14 55

# %%
print(2+2)
# Out:
# 4

# %%
print(3-3)
# Out:
# 0

# %% [markdown]
# # Data
#
#     Text >>>>>>   string >>>> str 'this is a text'
#
#     Numerical Data
#         Whole Numbers >>>>> Integer >>>> int >>>> 37
#
#
#         Decimal Numbers >>>>> Float >>> float >>>> 46.4
#
#
#     Boolen Data :
#
#         True >> False >>> bool

# %% [markdown]
# # String

# %% [markdown]
# # Quotes

# %%
'this is a text'
# Out:
# 'this is a text'

# %%
# Type function 

its any object view data type

# %%
type('this is a text')
# Out:
# str

# %%
print(type('this is a text'))
# Out:
# <class 'str'>

# %% [markdown]
# # String
#
#
# Single Core
#
# double core
#
# single triple core
#
# double triple core

# %%
type('my name is ubaid')
# Out:
# str

# %%
 type(123)
# Out:
# int

# %%
type(5.5)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type('73')
# Out:
# str

# %%
type('5.5')
# Out:
# str

# %% [markdown]
# # String

# %%
print('this is a single core string')
# Out:
# this is a single core string

# %%
type('this is a single core string')
# Out:
# str

# %%
"this is a dobule core string"
# Out:
# 'this is a dobule core string'

# %%
type("this is a dobule core string")
# Out:
# str

# %%
'''this is a single triple core string'''
# Out:
# 'this is a single triple core string'

# %%
"""this is a double triple core string"""
# Out:
# 'this is a double triple core string'

# %%
'hello my name is 
ubaid'
# Out:
#   Cell In[49], line 1
#     'hello my name is
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('''hello my name is 
ubaid''')
# Out:
# hello my name is
# ubaid

# %%
single core double core >>>> 1 line string 

1 thriple core 2 thriple core >>> Multi Line string

# %%
"my first 
program"
# Out:
#   Cell In[51], line 1
#     "my first
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
type("""my first 
program""")
# Out:
# str

# %%
len('ubaid')
# Out:
# 5

# %%
len('my name is ali')
# Out:
# 14

# %%
len('1234')
# Out:
# 4

# %%
len(5.6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 len(5.6)
#
# TypeError: object of type 'float' has no len()

# %%
len(True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 len(True)
#
# TypeError: object of type 'bool' has no len()

# %%
# Variables Dtypes
