# %% [markdown]
# # Variables

# %%
# What is Variables

# %%
99
# Out:
# 99

# %%
'ubaid'
# Out:
# 'ubaid'

# %%
# What is Variables 

Variables is like a container it is use for data store

structure:
    
    variable_name=value

# %%
a=10

# %%
a
# Out:
# 10

# %%
a
# Out:
# 10

# %%
10
# Out:
# 10

# %%
a
# Out:
# 10

# %%
name='ali'

# %%
name
# Out:
# 'ali'

# %%
name
# Out:
# 'ali'

# %%
name='jameel'
age=18
weight=67.3
height=5.5

# %%
print(name)
# Out:
# jameel

# %%
print(age)
# Out:
# 18

# %%
print(weight)
# Out:
# 67.3

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(height)
# Out:
# float

# %%
type(weight)
# Out:
# float

# %%
id(name)
# Out:
# 2601573660336

# %%
id(age)
# Out:
# 140722035463496

# %%
id(weight)
# Out:
# 2601566589680

# %%
name='ali'
roll=28383
subject='maths'

# %%
name
# Out:
# 'ali'

# %%
roll
# Out:
# 28383

# %%
subject
# Out:
# 'maths'

# %%
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 name
#
# NameError: name 'name' is not defined

# %%
name='ali'
roll=28383
subject='maths'

# %%
product_name='surf excel'
price=50
weight_kg=1

# %%
a=10
b=5
c='ali'

# %%
age=10
height_feet=5.4
name='ali'

# %%
age
# Out:
# 10

# %%
height_feet
# Out:
# 5.4

# %%
name
# Out:
# 'ali'

# %%
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 name
#
# NameError: name 'name' is not defined

# %%
age
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 age
#
# NameError: name 'age' is not defined

# %%
age=10
height_feet=5.4
name='ali'

# %%
age
# Out:
# 10

# %%
age=10
height_feet=5.4
name='ali'

# %%
age
# Out:
# 10

# %%
age
# Out:
# 10

# %%
product_name='tesla'
price=1000000
color='pink'
engine='4000cc'

# %%
product_name
# Out:
# 'tesla'

# %%
price
# Out:
# 1000000

# %%
color
# Out:
# 'pink'

# %%
engine
# Out:
# '4000cc'

# %%
product_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 product_name
#
# NameError: name 'product_name' is not defined

# %%
engine
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 engine
#
# NameError: name 'engine' is not defined

# %%
engine
# Out:
# '4000cc'

# %%
product_name
# Out:
# 'tesla'

# %%
# Variables Rules 

    1 do not use space in variable name
    2 do not start with number
    3 do not use any python operator
    4 do not use any python reveserved word

# %%
full name='ali'
# Out:
#   Cell In[7], line 1
#     full name='ali'
#          ^
# SyntaxError: invalid syntax

# %%
full_name='ali'

# %%
full_name
# Out:
# 'ali'

# %%
1_subject='physis'
# Out:
#   Cell In[10], line 1
#     1_subject='physis'
#      ^
# SyntaxError: invalid decimal literal

# %%
subject_1='physis'

# %%
subject_1
# Out:
# 'physis'

# %%
_2suject='maths'

# %%
_suject
# Out:
# 'maths'

# %%
1_kg=2
# Out:
#   Cell In[17], line 1
#     1_kg=2
#      ^
# SyntaxError: invalid decimal literal

# %%
full+name='hassan ali'
# Out:
#   Cell In[18], line 1
#     full+name='hassan ali'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
full-name='ubaid'
# Out:
#   Cell In[19], line 1
#     full-name='ubaid'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# # Reversed Words
# class if else for while and or global try except

# %%
class='matric'
# Out:
#   Cell In[20], line 1
#     class='matric'
#          ^
# SyntaxError: invalid syntax

# %%
Class='matric'

# %%
Class
# Out:
# 'matric'

# %%
if=91
# Out:
#   Cell In[23], line 1
#     if=91
#       ^
# SyntaxError: invalid syntax

# %%
else=38
# Out:
#   Cell In[24], line 1
#     else=38
#     ^
# SyntaxError: invalid syntax

# %%
print='hello'

# %%
print
# Out:
# 'hello'

# %%
len='jdjd'

# %%
len
# Out:
# 'jdjd'

# %%
len()

# %%
name-'hashim'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 name-'hashim'
#
# NameError: name 'name' is not defined

# %% [markdown]
# # Update Variable

# %%
age=18

# %%
age=12

# %%
age
# Out:
# 12

# %%
age=18
age=12
age=9

# %%
age
# Out:
# 9

# %%
id(age)
# Out:
# 140722045555752

# %%
name='hassan'
name='ali'

# %%
name
# Out:
# 'ali'

# %%
id(name)
# Out:
# 2226914184496

# %%
num_1=10
num_2=20

# %%
result=num_1+num_2

# %%
result
# Out:
# 30

# %%
result
# Out:
# 30

# %%
result=10

# %%
result
# Out:
# 10

# %%
c=num_1+10

# %%
c
# Out:
# 20

# %%
id(age)
# Out:
# 140722045555752
