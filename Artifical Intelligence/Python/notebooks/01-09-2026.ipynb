# %% [markdown]
# ## Strings
#     what is string in python ?
#
#     In Python string is an Data structure that can store collection of charcters
#
#
#         1 : string are immutable
#
#         2 : You can access Any sting part using Indexing
#
#
#         You can make string by single quotes dobule quotes triples quotes

# %%
single_quote_str='i am a single quote string'

# %%
double_quote_str="i am a double quote string"

# %%
triple='''I am a single triple core quotes'''

# %%
triple
# Out:
# 'I am a single triple core quotes'

# %%
type(triple)
# Out:
# str

# %%
# String Operations 

    +  >>>>>   Concatenation
    
    *  >>>>>>>  Repeat

# %%
first_name='ali '
last_name='Khan'

# %%
first_name+last_name
# Out:
# 'aliKhan'

# %%
99+88
# Out:
# 187

# %%
'99'+'78'+'99'
# Out:
# '997899'

# %%
print(type(first_name))
# Out:
# <class 'str'>

# %%
first_name
# Out:
# 'ali'

# %%
last_name
# Out:
# 'Khan'

# %%
first_name='ali '

middle_name='ahmed '
last_name='Khan'

# %%
first_name+middle_name+last_name
# Out:
# 'ali ahmed Khan'

# %%
first_name='ali'

middle_name='ahmed'
last_name='Khan'

# %%
first_name+' '+middle_name+' '+last_name
# Out:
# 'ali ahmed Khan'

# %%
first_name
# Out:
# 'ali'

# %%
last_name
# Out:
# 'Khan'

# %%
middle_name
# Out:
# 'ahmed'

# %%
full_name=first_name+' '+middle_name+' '+last_name

# %%
full_name
# Out:
# 'ali ahmed Khan'

# %%
first_name+'3'
# Out:
# 'ali3'

# %%
first_name
# Out:
# 'ali'

# %%
first_name*3
# Out:
# 'alialiali'

# %%
middle_name*10
# Out:
# 'ahmedahmedahmedahmedahmedahmedahmedahmedahmedahmed'

# %%
middle_name*15
# Out:
# 'ahmedahmedahmedahmedahmedahmedahmedahmedahmedahmedahmedahmedahmedahmedahmed'

# %%
(middle_name+' ')*3
# Out:
# 'ahmed ahmed ahmed '

# %% [markdown]
# # Indexing
# ## what is indexing
#
#     In String Indexing is a postion to access an character
#
#
# ## There are Two Types of Indexing
#
#     Postive Indexing  >>>>>>>>>   It can start from 0
#
#     Negative Indexing >>>>>>>>>>  It can start from -1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Postive Indexing

# %%
sentence='Python Programming'

# %%
sentence[0]
# Out:
# 'P'

# %%
sentence[1]
# Out:
# 'y'

# %%
sentence[2]
# Out:
# 't'

# %%
sentence[3]
# Out:
# 'h'

# %%
sentence[5]
# Out:
# 'n'

# %%
sentence[6]
# Out:
# ' '

# %%
sentence[9]
# Out:
# 'o'

# %%
full_name='nasir hussain'

# %%
full_name[2]
# Out:
# 's'

# %%
full_name[20]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 full_name[20]
#
# IndexError: string index out of range

# %%
len(full_name)-1
# Out:
# 12

# %%
num=5

# %%
full_name[num]
# Out:
# ' '

# %%
len(full_name)-1
# Out:
# 12

# %%
full_name
# Out:
# 'nasir hussain'

# %%
full_name[len(full_name)-1]
# Out:
# 'n'

# %%
full_name['5']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 full_name['5']
#
# TypeError: string indices must be integers, not 'str'

# %%
full_name
# Out:
# 'nasir hussain'

# %%
loc=9

# %%
full_name[loc]
# Out:
# 's'

# %%
full_name[9]
# Out:
# 's'

# %%
full_name[len(full_name)-4]
# Out:
# 's'

# %%
Postive >>>>  start from 0 end >>>> len -1

# %%
sentence='My name is ali i am 18 years old'

# %%
sentence[0]
# Out:
# 'M'

# %%
sentence[3]
# Out:
# 'n'

# %%
sentence[0+3]
# Out:
# 'n'

# %%
sentence[0]
# Out:
# 'M'

# %%
type(sentence[0])
# Out:
# str

# %%
result=sentence[0]+sentence[3]

# %%
sentence
# Out:
# 'My name is ali i am 18 years old'

# %%
result
# Out:
# 'Mn'

# %%
sentence
# Out:
# 'My name is ali i am 18 years old'

# %%
sentence[20]
# Out:
# '1'

# %%
sentence[21]
# Out:
# '8'

# %%
sentence[29]
# Out:
# 'o'

# %%
b=sentence[20]+sentence[21]+sentence[29]

# %%
b
# Out:
# '18o'

# %%
# Negative Indexing
